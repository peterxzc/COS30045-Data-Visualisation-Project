# %%
import pandas as pd

# %%
ucdp = pd.read_csv('../raw_data/ucdp-prio-acd-171.csv')
ucdp.dtypes
# Out:
# conflictid      int64
# location       object
# sidea          object
# sidea2nd       object
# side b         object
# sidebid        object
# sideb2nd       object
# incomp          int64
# terr           object
# year            int64
# intensity       int64
# cumint          int64
# type            int64
# startdate      object
# startprec       int64
# startdate2     object
# startprec2      int64
# epend           int64
# ependdate      object
# ependprec     float64
# gwnoa          object
# gwnoa2nd       object
# gwnob          object
# gwnob2nd       object
# gwnoloc        object
# region         object
# version       float64
# dtype: object

# %%
ucdp['location'].value_counts()
# Out:
# Myanmar (Burma)                          270
# India                                    170
# Ethiopia                                 119
# Philippines                              100
# Israel                                    74
# Iraq                                      58
# Colombia                                  53
# Angola                                    49
# Sudan                                     47
# Indonesia                                 46
# Afghanistan                               41
# Russia (Soviet Union)                     40
# Iran                                      40
# Uganda                                    39
# Turkey                                    38
# Chad                                      38
# Cambodia (Kampuchea)                      38
# Algeria                                   36
# Guatemala                                 34
# Pakistan                                  31
# South Africa                              30
# ...

# %%
ucdp[ucdp['year'] >= 1985]
# Out:
#       conflictid                                           location  \
# 33           205                                               Iran
# 34           205                                               Iran
# 35           205                                               Iran
# 36           205                                               Iran
# 37           205                                               Iran
# 38           205                                               Iran
# 39           205                                               Iran
# 75           209                                        Philippines
# 76           209                                        Philippines
# 77           209                                        Philippines
# 78           209                                        Philippines
# 79           209                                        Philippines
# 80           209                                        Philippines
# ...
